# %%
from pycaret.datasets import get_data

# %%
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *

# %%
s = setup(data, target = 'charges', session_id = 1)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# #T_0f42928a_e4a2_11ea_9234_00155d2e332brow0_col1{
#             background-color:  yellow;
#         }</style><table id="T_0f42928a_e4a2_11ea_9234_00155d2e332b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f42928a_e4a2_11ea_9234_00155d2e332blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0f42928a_e4a2_11ea_9234_00155d2e332brow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0f42928a_e4a2_11ea_9234_00155d2e332brow0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_0f42928a_e4a2_11ea_9234_00155d2e332blevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
lr_model = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_37ef98e4_e4a2_11ea_a622_00155d2e332brow10_col0,#T_37ef98e4_e4a2_11ea_a622_00155d2e332brow10_col1,#T_37ef98e4_e4a2_11ea_a622_00155d2e332brow10_col2,#T_37ef98e4_e4a2_11ea_a622_00155d2e332brow10_col3,#T_37ef98e4_e4a2_11ea_a622_00155d2e332brow10_col4,#T_37ef98e4_e4a2_11ea_a622_00155d2e332brow10_col5{
#             background:  yellow;
#         }</style><table id="T_37ef98e4_e4a2_11ea_a622_00155d2e332b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37ef98e4_e4a2_11ea_a622_00155d2e332blevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(lr_model)

# %%
s2  = setup(data, target='charges', session_id=123,
           normalize = True,
           polynomial_features = True,
           trigonometry_features = True,
           feature_interaction=True,
           bin_numeric_features=['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# #T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332brow15_col1,#T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332brow25_col1,#T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332brow32_col1,#T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332brow34_col1,#T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332brow39_col1{
#             background-color:  yellow;
#         }</style><table id="T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e0c94e4a_e4a2_11ea_a5d5_00155d2e332brow0_col0" class="data row0 col0" >session_id</td>
# ...

# %%
lr_feat_process = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_a2509b70_e4a3_11ea_bbee_00155d2e332brow10_col0,#T_a2509b70_e4a3_11ea_bbee_00155d2e332brow10_col1,#T_a2509b70_e4a3_11ea_bbee_00155d2e332brow10_col2,#T_a2509b70_e4a3_11ea_bbee_00155d2e332brow10_col3,#T_a2509b70_e4a3_11ea_bbee_00155d2e332brow10_col4,#T_a2509b70_e4a3_11ea_bbee_00155d2e332brow10_col5{
#             background:  yellow;
#         }</style><table id="T_a2509b70_e4a3_11ea_bbee_00155d2e332b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2509b70_e4a3_11ea_bbee_00155d2e332blevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(lr_feat_process)

# %%
interpret_model(lr_feat_process)

# %%
save_model(lr_feat_process, 'deployment_28042020')
# Out:
# Transformation Pipeline and Model Succesfully Saved
